# %% [markdown]
# <a href="https://colab.research.google.com/github/pemson-18/pemson-18/blob/main/Python_Worksheet_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introductory Python Worksheet - Part 1
#
# **Duration:** 60–75 minutes
#
# Follow the tasks below in JupyterLab. Try each task in a new cell and don't peek at the solution notebook until you're done.

# %% [markdown]
# ## Objectives
# - Practice basic Python: variables, lists, loops, functions
#
# ---

# %% [markdown]
# ## Task 1 — Simple arithmetic and variables
# 1. Create variables `a = 12` and `b = 5`.
# 2. Compute and print their sum, difference, product, integer division, and remainder.
#
# (Write code in the cell below)

# %% [markdown]
# ## Task 2 — Strings and lists
# 1. Create a list `fruits = ['apple','banana','mango']`.
# 2. Add 'orange' to the list, sort it, and print the 2nd item.
#
# (Write code in the cell below)

# %% [markdown]
# ## Task 3 — Loop & conditionals
# Write a loop that prints all even numbers between 0 and 20 (inclusive).

# %% [markdown]
# ## Task 4 — Functions
# 1. Define a function `is_prime(n)` that returns `True` if `n` is prime, else `False`.
# 2. Test it for numbers 1..20 and print the primes.
