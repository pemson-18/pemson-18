# %% [markdown]
# <a href="https://colab.research.google.com/github/pemson-18/pemson-18/blob/main/Python_Worksheet_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introductory Python Worksheet - Part 2
#
# **Duration:** 60–75 minutes
#
# Follow the tasks below in JupyterLab. Try each task in a new cell and don't peek at the solution notebook until you're done.

# %% [markdown]
# ## Task 5 — Working with CSV (pandas)
# 1. Create a small dataframe with columns `name` and `score` and 5 rows of sample data.
# 2. Save it to `students.csv` and then read it back.
# 3. Print the average score.

# %% [markdown]
# ## Task 6 — Plotting
# Using matplotlib, plot the scores from Task 5 as a bar chart. Label axes and add a title.
