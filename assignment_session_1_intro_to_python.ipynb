# %% [markdown]
# <a href="https://colab.research.google.com/github/pemson-18/pemson-18/blob/main/assignment_session_1_intro_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 1 — Intro to Python for Scientific Computing (Google Colab) - Assignment
#
# ## Worksheet (Exercises)
#
# Faculty audience: Physics, Chemistry, Mathematics.
#
# Follow the cells below. Each problem has a **Task** cell (try yourself) and a **Hint** cell. Run code cells to test. After you attempt all problems, open the **Solutions** section at the end to compare.
#
# ----

# %% [markdown]
# ## Warm-up: Python & NumPy basics
#
# **Task 1.1**: Create a NumPy array `x` containing 100 evenly spaced values between 0 and 10. Compute `y = 2*x + 1` using vectorized operations and show the first 5 elements of `y`.
#
# **Hint:** use `np.linspace` and elementwise arithmetic.

# %%
# Task 1.1 - Try here
import numpy as np

# YOUR CODE HERE

# %% [markdown]
# ----

# %% [markdown]
# ## Quick Plot
#
# **Task 1.2**: Plot `y` vs `x` (line plot) with axis labels and a title.

# %%
# Task 1.2 - Try here
import matplotlib.pyplot as plt

# YOUR CODE HERE

# %% [markdown]
# ----

# %% [markdown]
# ## Problem A — Physics: Simple Harmonic Motion (SHM)
#
# **Context:** A mass-spring system with amplitude `A=1.0` m and angular frequency `omega=2.0` rad/s.
#
# **Task A.1**: Generate `t` from 0 to 10 seconds (1000 points). Compute displacement `x(t)=A*cos(omega*t)` and plot it.
#
# **Task A.2**: Compute and print the period `T` and show the first three `(t,x)` pairs.
#
# **Hint:** `T = 2*pi/omega`.

# %%
# Task A - Try here
import numpy as np
import matplotlib.pyplot as plt

# YOUR CODE HERE

# %% [markdown]
# ----

# %% [markdown]
# ## Problem B — Chemistry: First-order Reaction
#
# **Context:** A reactant follows first-order kinetics with rate constant `k=0.3` s^-1 and initial concentration `C0=1.0` mol/L.
#
# **Task B.1**: Compute concentration `C(t)=C0*exp(-k*t)` for `t` from 0 to 15 s (200 points). Plot concentration vs time.
#
# **Task B.2**: Find time `t_half` when concentration falls to half of `C0` (analytical expression) and verify numerically.

# %%
# Task B - Try here
import numpy as np
import matplotlib.pyplot as plt

# YOUR CODE HERE

# %% [markdown]
# ----

# %% [markdown]
# ## Problem C — Mathematics: Quadratic Curve & Curve-Fit
#
# **Context:** Generate noisy data from `y = 3x^2 - 2x + 1` on x in [-2,2].
#
# **Task C.1**: Create 50 points, add Gaussian noise (sigma=2.0). Plot scatter of noisy data and true curve.
#
# **Task C.2**: Fit a quadratic polynomial using `np.polyfit` and report coefficients. Plot fitted curve over scatter.

# %%
# Task C - Try here
import numpy as np
import matplotlib.pyplot as plt

# YOUR CODE HERE
